# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///music.db")
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine)

# save references to each table
songs = Base.classes

# %%
Base.classes

# %%
Base.classes.keys()
# Out:
# ['topmusic']

# %%
Music = Base.classes.topmusic

# %%
session = Session(engine)

find_one = session.query(Music.popularity).order_by(Music.popularity.desc()).first()
find_one
# Out:
# (100,)

# %%
find_one = session.query(Music.popularity, Music.artistname, Music.trackname).\
    order_by(Music.popularity.desc()).\
        filter(Music.popularity >= 85).all()
find_one
# Out:
# [(100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
#  (100, 'Tate McRae', 'greedy'),
# ...

# %%
countries = session.query(Music.country, Music.artistname, Music.trackname).\
    order_by(Music.country).all()
countries
len(countries)
# Out:
# 2862

# %%
countries2 = session.query(Music.country, Music.trackname, Music.artistname, Music.popularity).\
    order_by(Music.country).\
    filter(Music.country == 'Global').limit(10)
countries2
# Out:
# [('Global', 'Standing Next to You', 'Jung Kook', 91),
#  ('Global', 'greedy', 'Tate McRae', 100),
#  ('Global', 'Seven (feat. Latto) (Explicit Ver.)', 'Jung Kook', 82),
#  ('Global', "Is It Over Now? (Taylor's Version) (From The Vault)", 'Taylor Swift', 93),
#  ('Global', 'PERRO NEGRO', 'Bad Bunny', 97),
#  ('Global', 'Paint The Town Red', 'Doja Cat', 89),
#  ('Global', 'Cruel Summer', 'Taylor Swift', 99),
#  ('Global', 'MONACO', 'Bad Bunny', 98),
#  ('Global', 'My Love Mine All Mine', 'Mitski', 97),
#  ('Global', 'Strangers', 'Kenya Grace', 98),
#  ('Global', 'Water', 'Tyla', 95),
#  ('Global', "Now That We Don't Talk (Taylor's Version) (From The Vault)", 'Taylor Swift', 91),
#  ('Global', 'HARLEY QUINN', 'Fuerza Regida', 90),
#  ('Global', '3D (feat. Jack Harlow)', 'Jung Kook', 89),
#  ('Global', 'QLONA', 'KAROL G', 94),
#  ('Global', 'Agora Hills', 'Doja Cat', 82),
#  ('Global', 'Que Onda', 'Calle 24', 94),
#  ('Global', 'I Wanna Be Yours', 'Arctic Monkeys', 95),
# ...
